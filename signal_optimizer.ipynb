# %% [markdown]
# ## Full Analysis for October 17th

# %%
# !python3 ./traffic_singal_optimizer.py \
--mode 'optimize_daily' \
--day_offset 1 \
--gens 50 \
--model_path "./traffic_speed/checkpoint/model_dnn_lr0.001_seed9999_best.keras" \
--scaler_path "./traffic_speed/checkpoint/scaler_dnn_lr0.001_seed9999.pkl" \
--data_path "./data/traffic_speed/test_X.pkl" \
--label_path "./data/traffic_speed/test_Y.pkl"

# %% [markdown]
# ## Analysis of peak hour (8:00 AM) on October 17th
#
# day offset 1 = 10/17

# %%
# !python3 ./traffic_singal_optimizer.py \
--mode 'optimize_single' \
--day_offset 1 \
--hour 8 \
--gens 50 \
--model_path "./traffic_speed/checkpoint/model_dnn_lr0.001_seed9999_best.keras" \
--scaler_path "./traffic_speed/checkpoint/scaler_dnn_lr0.001_seed9999.pkl" \
--data_path "./data/traffic_speed/test_X.pkl" \
--label_path "./data/traffic_speed/v2/test_Y.pkl"

# %%
# !python3 ./traffic_singal_optimizer.py \
--mode 'analyze_single' \
--day_offset 1 \
--hour 8 \
--gens 50 \
--model_path "./traffic_speed/checkpoint/model_dnn_lr0.001_seed9999_best.keras" \
--scaler_path "./traffic_speed/checkpoint/scaler_dnn_lr0.001_seed9999.pkl" \
--data_path "./data/traffic_speed/test_X.pkl" \
--label_path "./data/traffic_speed/test_Y.pkl"

# %% [markdown]
# ## Analysis of non-peak hour (3:00 AM) on October 17th

# %%
# !python3 ./traffic_singal_optimizer.py \
--mode 'optimize_single' \
--day_offset 1 \
--hour 3 \
--gens 50 \
--model_path "./traffic_speed/checkpoint/model_dnn_lr0.001_seed9999_best.keras" \
--scaler_path "./traffic_speed/checkpoint/scaler_dnn_lr0.001_seed9999.pkl" \
--data_path "./data/traffic_speed/test_X.pkl" \
--label_path "./data/traffic_speed/test_Y.pkl"

# %%
# !python3 ./traffic_singal_optimizer.py \
--mode 'analyze_single' \
--day_offset 1 \
--hour 3 \
--gens 50 \
--model_path "./traffic_speed/checkpoint/model_dnn_lr0.001_seed9999_best.keras" \
--scaler_path "./traffic_speed/checkpoint/scaler_dnn_lr0.001_seed9999.pkl" \
--data_path "./data/traffic_speed/test_X.pkl" \
--label_path "./data/traffic_speed/test_Y.pkl"
